# %% [markdown]
# # Welcome to Full Stack Machine Learning's Week 4 Project!
#
# In the final week, you will return to the workflow you built last week on the [taxi dataset](https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page).

# %% [markdown]
# ## Task 1: Deploy the champion
# Use what you have learned in the last two weeks to make necessary modifications and to deploy your latest version of the `TaxiFarePrediction` flow to Argo. Use `--branch champion` to denote this deployment as the champion model.

# %%
# %%writefile ../flows/cloud/taxiprediction_champion.py
from metaflow import FlowSpec, step, card, conda_base, project, current, Parameter, Flow, trigger, retry, timeout,catch
from metaflow.cards import Markdown, Table, Image, Artifact

URL = "https://outerbounds-datasets.s3.us-west-2.amazonaws.com/taxi/latest.parquet"
DATETIME_FORMAT = '%Y-%m-%d %H:%M:%S'

@trigger(events=['s3'])
@conda_base(libraries={'pandas': '1.4.2', 'pyarrow': '11.0.0', 'numpy': '1.21.2', 'scikit-learn': '1.1.2'})
@project(name="taxi_fare_prediction")
class TaxiFarePrediction(FlowSpec):

    data_url = Parameter("data_url", default=URL)

    def transform_features(self, df):

        obviously_bad_data_filters = [
            df.fare_amount > 0,         
            df.trip_distance <= 100,    
            df.trip_distance > 0,
            df.passenger_count > 0,
            df.mta_tax > 0,
            df.tip_amount >= 0,
            df.tolls_amount >= 0,
            df.total_amount > 0,
            df.PULocationID !=df.DOLocationID,
            df.hour > 0
        ]

        for f in obviously_bad_data_filters:
            df = df[f]

        
        return df

    @catch(var="read_failure")
    @retry(times=4)
    @timeout(minutes=10)
    @step
    def start(self):

        import pandas as pd
        from sklearn.model_selection import train_test_split

        self.df = self.transform_features(pd.read_parquet(self.data_url))

        self.X = self.df["trip_distance"].values.reshape(-1, 1)
        self.y = self.df["total_amount"].values
        self.next(self.linear_model)

    @step
    def linear_model(self):
        from sklearn.linear_model import LinearRegression

        self.model = LinearRegression()

        self.next(self.validate)
                
    
    def gather_sibling_flow_run_results(self):

        # storage to populate and feed to a Table in a Metaflow card
        rows = []

        # loop through runs of this flow 
        for run in Flow(self.__class__.__name__):
            if run.id != current.run_id:
                if run.successful:
                    icon = "✅" 
                    msg = "OK"
                    score = str(run.data.scores.mean())
                else:
                    icon = "❌"
                    msg = "Error"
                    score = "NA"
                    for step in run:
                        for task in step:
                            if not task.successful:
                                msg = task.stderr
                row = [Markdown(icon), Artifact(run.id), Artifact(run.created_at.strftime(DATETIME_FORMAT)), Artifact(score), Markdown(msg)]
                rows.append(row)
            else:
                rows.append([Markdown("✅"), Artifact(run.id), Artifact(run.created_at.strftime(DATETIME_FORMAT)), Artifact(str(self.scores.mean())), Markdown("This run...")])
        return rows
                
    
    @card(type="corise")
    @step
    def validate(self):
        from sklearn.model_selection import cross_val_score
        self.scores = cross_val_score(self.model, self.X, self.y, cv=5,scoring='r2')
        current.card.append(Markdown("# Taxi Fare Prediction Champion Results"))
        current.card.append(Table(self.gather_sibling_flow_run_results(), headers=["Pass/fail", "Run ID", "Created At", "R^2 score", "Stderr"]))
        self.next(self.end)


    @step
    def end(self):
        self.model_type = "baseline"
        print("Score = %s" % self.scores.mean())


if __name__ == "__main__":
    TaxiFarePrediction()
# Out:
# Overwriting ../flows/cloud/taxiprediction_champion.py

# %%
! python ../flows/cloud/taxiprediction_champion.py --environment=conda --production --branch champion argo-workflows create
# Out:
# Metaflow 2.8.6+ob(v1) executing TaxiFarePrediction for user:sandbox
# Project: taxi_fare_prediction, Branch: prod.champion
# Validating your flow...
#     The graph looks good!
# Running pylint...
#     Pylint is happy!
# Deploying taxifareprediction.prod.champion.taxifareprediction to Argo Workflows...
#
# The namespace of this production flow is
#     production:mfprj-ovzw7jjg7psagpyw-0-pcke
# To analyze results of this production flow add this line in your notebooks:
#     namespace("production:mfprj-ovzw7jjg7psagpyw-0-pcke")
# If you want to authorize other people to deploy new versions of this flow to Argo Workflows, they need to call
#     argo-workflows create --authorize mfprj-ovzw7jjg7psagpyw-0-pcke
# when deploying this flow to Argo Workflows for the first time.
# See "Organizing Results" at https://docs.metaflow.org/ for more information about production tokens.
#
# Bootstrapping conda environment...(this could take a few minutes)
# Workflow taxifareprediction.prod.champion.taxifareprediction for flow TaxiFarePrediction pushed to Argo Workflows successfully.
#
# Note that the flow was deployed with a modified name due to Kubernetes naming conventions
# on Argo Workflows. The original flow name is stored in the workflow annotation.
#
# What will trigger execution of the workflow:
#     This workflow triggers automatically when the upstream s3 event is/are published.

# %%
! python ../flows/cloud/taxiprediction_champion.py --environment=conda --production --branch champion argo-workflows trigger
# Out:
# Metaflow 2.8.6+ob(v1) executing TaxiFarePrediction for user:sandbox
# Project: taxi_fare_prediction, Branch: prod.champion
# Validating your flow...
#     The graph looks good!
# Running pylint...
#     Pylint is happy!
# Workflow taxifareprediction.prod.champion.taxifareprediction triggered on Argo Workflows (run-id argo-taxifareprediction.prod.champion.taxifareprediction-mp65m).
# See the run in the UI at https://ui-pw-535851483.outerbounds.dev/TaxiFarePrediction/argo-taxifareprediction.prod.champion.taxifareprediction-mp65m

# %% [markdown]
# ## Task 2: Build the challenger
# Develop a second model, by using the same `TaxiFarePrediction` architecture. Then, deploy the flow to Argo as the `--branch challenger`.
# <br>
# <br>
# Hint: Modify the `linear_model` step.
# <br>
# Bonus: Write a paragraph summary of how you developed the second model and tested it before deploying the challenger flow. Let us know in Slack what you found challenging about the task?

# %%
# %%writefile ../flows/cloud/taxiprediction_multiple_models_flow.py
from metaflow import FlowSpec, step, card, conda_base, current, Parameter, Flow, trigger
from metaflow.cards import Markdown, Table, Image, Artifact

URL = "https://outerbounds-datasets.s3.us-west-2.amazonaws.com/taxi/latest.parquet"
DATETIME_FORMAT = '%Y-%m-%d %H:%M:%S'

@trigger(events=['s3'])
@conda_base(libraries={'pandas': '1.4.2', 'pyarrow': '11.0.0', 'numpy': '1.21.2', 'scikit-learn': '1.1.2', 'lightgbm' : '3.3.5','xgboost' : '1.7.4'})
class TaxiFarePrediction(FlowSpec):

    data_url = Parameter("data_url", default=URL)

    def transform_features(self, df):

        obviously_bad_data_filters = [
            df.fare_amount > 0,         
            df.trip_distance <= 100,    
            df.trip_distance > 0,
            df.passenger_count > 0,
            df.mta_tax > 0,
            df.tip_amount >= 0,
            df.tolls_amount >= 0,
            df.total_amount > 0,
            df.PULocationID !=df.DOLocationID,
            df.hour > 0
        ]

        for f in obviously_bad_data_filters:
            df = df[f]

        
        return df

    @step
    def start(self):

        import pandas as pd
        from sklearn.model_selection import train_test_split

        self.df = self.transform_features(pd.read_parquet(self.data_url))
 
        self.X = self.df["trip_distance"].values.reshape(-1, 1)
        self.y = self.df["total_amount"].values
        self.next(self.model_linear_reg,self.model_elasticnet, self.model_bayesianridge,self.model_xgboost,self.model_lightgbm)
        
    @step
    def model_linear_reg(self):
        from sklearn.linear_model import LinearRegression
        from sklearn.model_selection import cross_val_score
        

        self.reg = LinearRegression()
        self.scores = cross_val_score(self.reg, self.X, self.y, cv=5,scoring='r2')
        print("scores LR", self.scores)
        self.next(self.choose_model)

    @step
    def model_elasticnet(self):
        from sklearn.linear_model import ElasticNet
        from sklearn.model_selection import cross_val_score
        
        self.reg = ElasticNet()
        self.scores = cross_val_score(self.reg, self.X, self.y, cv=5,scoring='r2')
        print("scores EN", self.scores)
        self.next(self.choose_model) 




    @step
    def model_bayesianridge(self):
        from sklearn.linear_model import BayesianRidge
        from sklearn.model_selection import cross_val_score
        
        
        self.reg = BayesianRidge()
        self.scores = cross_val_score(self.reg, self.X, self.y, cv=5,scoring='r2')
        print("scores BR", self.scores)
        self.next(self.choose_model)
    

    @step
    def model_xgboost(self):
        from xgboost import XGBRegressor
        from sklearn.model_selection import cross_val_score
        
       
        self.reg = XGBRegressor() 
        self.scores = cross_val_score(self.reg, self.X, self.y, cv=5,scoring='r2')
        print("scores XG", self.scores)
        self.next(self.choose_model)

    @step
    def model_lightgbm(self):
        from lightgbm import LGBMRegressor
        from sklearn.model_selection import cross_val_score
        
       
        self.reg = LGBMRegressor()
        self.scores = cross_val_score(self.reg, self.X, self.y, cv=5,scoring='r2')
        print("scores LG", self.scores)
        self.next(self.choose_model)

    @card(type="corise")
    @step
    def choose_model(self, inputs):
        """
        find 'best' model
        """
        import numpy as np

        def score(inp):
            return inp.reg, np.mean(inp.scores)

        self.results = sorted(map(score, inputs), key=lambda x: -x[1])
        print(self.results)
        self.model = self.results[0][0]
        current.card.append(Markdown("# Taxi Fare Prediction Multiple Model Results"))
        current.card.append(Artifact(self.results[0][1],self.results[0][0]))
        current.card.append(Artifact(self.results[1][1],self.results[1][0]))
        current.card.append(Artifact(self.results[2][1],self.results[2][0]))
        current.card.append(Artifact(self.results[3][1],self.results[3][0]))
        current.card.append(Artifact(self.results[4][1],self.results[4][0]))
        self.next(self.end)

    
    @step
    def end(self):
        print("Scores:")
        print("\n".join("%s %f" % res for res in self.results))
        



if __name__ == "__main__":
    TaxiFarePrediction()
# Out:
# Overwriting ../flows/cloud/taxiprediction_multiple_models_flow.py

# %%
! python ../flows/cloud/taxiprediction_multiple_models_flow.py --environment=conda run
# Out:
# Metaflow 2.8.6+ob(v1) executing TaxiFarePrediction for user:sandbox
# Validating your flow...
#     The graph looks good!
# Running pylint...
#     Pylint is happy!
# Bootstrapping conda environment...(this could take a few minutes)
# 2023-05-20 15:47:06.569 Workflow starting (run-id 895), see it in the UI at https://ui-pw-535851483.outerbounds.dev/TaxiFarePrediction/895
# 2023-05-20 15:47:07.524 [895/start/4593 (pid 32190)] Task is starting.
# 2023-05-20 15:47:13.370 [895/start/4593 (pid 32190)] Task finished successfully.
# 2023-05-20 15:47:14.222 [895/model_linear_reg/4594 (pid 32271)] Task is starting.
# 2023-05-20 15:47:14.954 [895/model_elasticnet/4595 (pid 32283)] Task is starting.
# 2023-05-20 15:47:16.042 [895/model_bayesianridge/4596 (pid 32315)] Task is starting.
# 2023-05-20 15:47:17.374 [895/model_xgboost/4597 (pid 32349)] Task is starting.
# 2023-05-20 15:47:19.789 [895/model_lightgbm/4598 (pid 32390)] Task is starting.
# 2023-05-20 15:47:19.789 [895/model_linear_reg/4594 (pid 32271)] scores LR [0.92329192 0.9200514  0.91637318 0.92437157 0.91577566]
# 2023-05-20 15:47:19.790 [895/model_elasticnet/4595 (pid 32283)] scores EN [0.92358606 0.91948365 0.91534007 0.92370968 0.91423504]
# 2023-05-20 15:47:20.437 [895/model_linear_reg/4594 (pid 32271)] Task finished successfully.
# 2023-05-20 15:47:21.839 [895/model_bayesianridge/4596 (pid 32315)] scores BR [0.92329193 0.9200514  0.91637317 0.92437157 0.91577566]
# 2023-05-20 15:47:23.353 [895/model_elasticnet/4595 (pid 32283)] Task finished successfully.
# 2023-05-20 15:47:24.535 [895/model_bayesianridge/4596 (pid 32315)] Task finished successfully.
# 2023-05-20 15:52:07.139 2 tasks are running: model_xgboost (1 running; 0 done), model_lightgbm (1 running; 0 done).
# 2023-05-20 15:52:07.139 No tasks are waiting in the queue.
# 2023-05-20 15:52:07.139 2 steps have not started: choose_model, end.
# 2023-05-20 15:56:02.835 [895/model_xgboost/4597 (pid 32349)] scores XG [0.93102297 0.92858468 0.92454042 0.9334379  0.92675682]
# 2023-05-20 15:56:17.537 [895/model_xgboost/4597 (pid 32349)] Task finished successfully.
# 2023-05-20 15:56:44.642 [895/model_lightgbm/4598 (pid 32390)] scores LG [0.92331201 0.92616394 0.91069231 0.92381137 0.91854585]
# 2023-05-20 15:56:46.531 [895/model_lightgbm/4598 (pid 32390)] Task finished successfully.
# 2023-05-20 15:56:47.396 [895/choose_model/4607 (pid 32538)] Task is starting.
# 2023-05-20 15:56:56.045 [895/choose_model/4607 (pid 32538)] [(XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 15:56:58.373 [895/choose_model/4607 (pid 32538)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 15:56:58.374 [895/choose_model/4607 (pid 32538)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 15:56:58.374 [895/choose_model/4607 (pid 32538)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 15:56:58.374 [895/choose_model/4607 (pid 32538)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 15:56:58.374 [895/choose_model/4607 (pid 32538)] interaction_constraints=None, learning_rate=None, max_bin=None,
# 2023-05-20 15:56:58.374 [895/choose_model/4607 (pid 32538)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 15:56:58.374 [895/choose_model/4607 (pid 32538)] max_delta_step=None, max_depth=None, max_leaves=None,
# 2023-05-20 15:56:58.374 [895/choose_model/4607 (pid 32538)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 15:56:58.374 [895/choose_model/4607 (pid 32538)] n_estimators=100, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 15:56:58.374 [895/choose_model/4607 (pid 32538)] predictor=None, random_state=None, ...), 0.9288685574855841), (LGBMRegressor(), 0.9205050977824436), (BayesianRidge(), 0.9199727463472419), (LinearRegression(), 0.9199727463264706), (ElasticNet(), 0.9192709030030786)]
# 2023-05-20 15:56:58.586 [895/choose_model/4607 (pid 32538)] Task finished successfully.
# 2023-05-20 15:56:59.492 [895/end/4608 (pid 32664)] Task is starting.
# 2023-05-20 15:57:00.461 [895/end/4608 (pid 32664)] Scores:
# 2023-05-20 15:57:01.320 [895/end/4608 (pid 32664)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 15:57:01.950 [895/end/4608 (pid 32664)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 15:57:01.950 [895/end/4608 (pid 32664)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 15:57:01.950 [895/end/4608 (pid 32664)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 15:57:01.950 [895/end/4608 (pid 32664)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 15:57:01.950 [895/end/4608 (pid 32664)] interaction_constraints=None, learning_rate=None, max_bin=None,
# 2023-05-20 15:57:01.950 [895/end/4608 (pid 32664)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 15:57:01.950 [895/end/4608 (pid 32664)] max_delta_step=None, max_depth=None, max_leaves=None,
# 2023-05-20 15:57:01.950 [895/end/4608 (pid 32664)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 15:57:01.950 [895/end/4608 (pid 32664)] n_estimators=100, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 15:57:01.950 [895/end/4608 (pid 32664)] predictor=None, random_state=None, ...) 0.928869
# 2023-05-20 15:57:01.950 [895/end/4608 (pid 32664)] LGBMRegressor() 0.920505
# 2023-05-20 15:57:01.951 [895/end/4608 (pid 32664)] BayesianRidge() 0.919973
# 2023-05-20 15:57:01.951 [895/end/4608 (pid 32664)] LinearRegression() 0.919973
# 2023-05-20 15:57:01.951 [895/end/4608 (pid 32664)] ElasticNet() 0.919271
# 2023-05-20 15:57:02.156 [895/end/4608 (pid 32664)] Task finished successfully.
# 2023-05-20 15:57:02.280 Done! See the run in the UI at https://ui-pw-535851483.outerbounds.dev/TaxiFarePrediction/895

# %%
# %%writefile ../flows/cloud/taxiprediction_xgboost_hyperopt.py
from metaflow import FlowSpec, step, card, conda_base, current, Parameter, Flow, trigger
from metaflow.cards import Markdown, Table, Image, Artifact

URL = "https://outerbounds-datasets.s3.us-west-2.amazonaws.com/taxi/latest.parquet"
DATETIME_FORMAT = '%Y-%m-%d %H:%M:%S'

@trigger(events=['s3'])
@conda_base(libraries={'pandas': '1.4.2', 'pyarrow': '11.0.0', 'numpy': '1.21.2', 'scikit-learn': '1.1.2', 'lightgbm' : '3.3.5','xgboost' : '1.7.4'})
class TaxiFarePrediction(FlowSpec):

    data_url = Parameter("data_url", default=URL)

    def transform_features(self, df):

    
        obviously_bad_data_filters = [
            df.fare_amount > 0,         
            df.trip_distance <= 100,    
            df.trip_distance > 0,
            df.passenger_count > 0,
            df.mta_tax > 0,
            df.tip_amount >= 0,
            df.tolls_amount >= 0,
            df.total_amount > 0,
            df.PULocationID !=df.DOLocationID,
            df.hour > 0
        ]

        for f in obviously_bad_data_filters:
            df = df[f]

        
        return df

    @step
    def start(self):

        import pandas as pd
        from sklearn.model_selection import train_test_split

        self.df = self.transform_features(pd.read_parquet(self.data_url))
 
        self.X = self.df["trip_distance"].values.reshape(-1, 1)
        self.y = self.df["total_amount"].values
        self.next(self.make_grid)

    @step
    def make_grid(self):
        from sklearn.model_selection import ParameterGrid
        param_values = {'n_estimators': [100, 250, 500],
                        'max_depth': [4, 5, 6],
                        'learning_rate': [0.05, 0.1, 0.25]}

        self.grid_points = list(
            ParameterGrid(param_values)
        )
        
        self.next(self.model_xgboost, 
                  foreach='grid_points')
    


    @step
    def model_xgboost(self):
        from xgboost import XGBRegressor
        from sklearn.model_selection import cross_val_score
    
        self.reg = XGBRegressor(**self.input) 
        self.scores = cross_val_score(self.reg, self.X, self.y, cv=5,scoring='r2')
        self.next(self.choose_model)

   

    @step
    def choose_model(self, inputs):
        """
        find 'best' model
        """
        import numpy as np

        def score(inp):
            return inp.reg,\
                   np.mean(inp.scores)

            
        self.results = sorted(map(score, inputs), key=lambda x: -x[1]) 
        self.model = self.results[0][0]
        
        self.next(self.end)

    @card(type="corise")
    @step
    def end(self):
        """
        End of flow!
        """
        print('Scores:')
        print('\n'.join('%s %f' % res for res in self.results))
        current.card.append(Markdown("Best Model"))
        current.card.append(Artifact(self.model))
        current.card.append(Markdown("Score of Best Model"))
        current.card.append(Artifact(self.results[0][1]))


  


if __name__ == "__main__":
    TaxiFarePrediction()
# Out:
# Overwriting ../flows/cloud/taxiprediction_xgboost_hyperopt.py

# %%
! python ../flows/cloud/taxiprediction_xgboost_hyperopt.py --environment=conda run
# Out:
# Metaflow 2.8.6+ob(v1) executing TaxiFarePrediction for user:sandbox
# Validating your flow...
#     The graph looks good!
# Running pylint...
#     Pylint is happy!
# Bootstrapping conda environment...(this could take a few minutes)
# 2023-05-20 16:08:54.897 Workflow starting (run-id 902), see it in the UI at https://ui-pw-535851483.outerbounds.dev/TaxiFarePrediction/902
# 2023-05-20 16:08:55.823 [902/start/4625 (pid 328)] Task is starting.
# 2023-05-20 16:09:01.519 [902/start/4625 (pid 328)] Task finished successfully.
# 2023-05-20 16:09:02.389 [902/make_grid/4628 (pid 409)] Task is starting.
# 2023-05-20 16:09:04.773 [902/make_grid/4628 (pid 409)] Foreach yields 27 child steps.
# 2023-05-20 16:09:04.773 [902/make_grid/4628 (pid 409)] Task finished successfully.
# 2023-05-20 16:09:05.678 [902/model_xgboost/4630 (pid 453)] Task is starting.
# 2023-05-20 16:09:06.412 [902/model_xgboost/4631 (pid 468)] Task is starting.
# 2023-05-20 16:09:07.524 [902/model_xgboost/4632 (pid 501)] Task is starting.
# 2023-05-20 16:09:08.770 [902/model_xgboost/4633 (pid 537)] Task is starting.
# 2023-05-20 16:09:11.344 [902/model_xgboost/4634 (pid 574)] Task is starting.
# 2023-05-20 16:09:14.970 [902/model_xgboost/4635 (pid 608)] Task is starting.
# 2023-05-20 16:09:19.654 [902/model_xgboost/4636 (pid 640)] Task is starting.
# 2023-05-20 16:09:26.043 [902/model_xgboost/4637 (pid 700)] Task is starting.
# 2023-05-20 16:09:32.644 [902/model_xgboost/4638 (pid 719)] Task is starting.
# 2023-05-20 16:09:39.935 [902/model_xgboost/4639 (pid 756)] Task is starting.
# 2023-05-20 16:09:49.143 [902/model_xgboost/4640 (pid 797)] Task is starting.
# 2023-05-20 16:09:57.040 [902/model_xgboost/4641 (pid 831)] Task is starting.
# 2023-05-20 16:10:06.342 [902/model_xgboost/4642 (pid 870)] Task is starting.
# 2023-05-20 16:10:16.636 [902/model_xgboost/4643 (pid 928)] Task is starting.
# 2023-05-20 16:10:25.340 [902/model_xgboost/4645 (pid 947)] Task is starting.
# 2023-05-20 16:10:38.542 [902/model_xgboost/4646 (pid 1005)] Task is starting.
# 2023-05-20 16:13:55.443 16 tasks are running: model_xgboost (16 running; 0 done).
# 2023-05-20 16:13:55.443 11 tasks are waiting in the queue.
# 2023-05-20 16:13:55.443 2 steps have not started: end, choose_model.
# 2023-05-20 16:18:56.241 16 tasks are running: model_xgboost (16 running; 0 done).
# 2023-05-20 16:18:56.241 11 tasks are waiting in the queue.
# 2023-05-20 16:18:56.241 2 steps have not started: end, choose_model.
# 2023-05-20 16:23:57.037 16 tasks are running: model_xgboost (16 running; 0 done).
# 2023-05-20 16:23:57.037 11 tasks are waiting in the queue.
# 2023-05-20 16:23:57.037 2 steps have not started: end, choose_model.
# 2023-05-20 16:24:31.838 [902/model_xgboost/4630 (pid 453)] Task finished successfully.
# 2023-05-20 16:24:42.035 [902/model_xgboost/4660 (pid 1073)] Task is starting.
# 2023-05-20 16:26:39.037 [902/model_xgboost/4639 (pid 756)] Task finished successfully.
# 2023-05-20 16:26:49.639 [902/model_xgboost/4661 (pid 1125)] Task is starting.
# 2023-05-20 16:28:24.337 [902/model_xgboost/4633 (pid 537)] Task finished successfully.
# 2023-05-20 16:28:35.244 [902/model_xgboost/4662 (pid 1177)] Task is starting.
# 2023-05-20 16:28:57.539 16 tasks are running: model_xgboost (16 running; 3 done).
# 2023-05-20 16:28:57.539 8 tasks are waiting in the queue.
# 2023-05-20 16:28:57.539 2 steps have not started: end, choose_model.
# 2023-05-20 16:31:32.038 [902/model_xgboost/4642 (pid 870)] Task finished successfully.
# 2023-05-20 16:31:41.144 [902/model_xgboost/4663 (pid 1229)] Task is starting.
# 2023-05-20 16:33:15.738 [902/model_xgboost/4636 (pid 640)] Task finished successfully.
# 2023-05-20 16:33:27.443 [902/model_xgboost/4664 (pid 1281)] Task is starting.
# 2023-05-20 16:33:57.746 16 tasks are running: model_xgboost (16 running; 5 done).
# 2023-05-20 16:33:57.746 6 tasks are waiting in the queue.
# 2023-05-20 16:33:57.746 2 steps have not started: end, choose_model.
# 2023-05-20 16:36:14.237 [902/model_xgboost/4646 (pid 1005)] Task finished successfully.
# 2023-05-20 16:36:27.443 [902/model_xgboost/4665 (pid 1333)] Task is starting.
# 2023-05-20 16:38:58.042 16 tasks are running: model_xgboost (16 running; 6 done).
# 2023-05-20 16:38:58.042 5 tasks are waiting in the queue.
# 2023-05-20 16:38:58.042 2 steps have not started: end, choose_model.
# 2023-05-20 16:43:58.646 16 tasks are running: model_xgboost (16 running; 6 done).
# 2023-05-20 16:43:58.646 5 tasks are waiting in the queue.
# 2023-05-20 16:43:58.646 2 steps have not started: end, choose_model.
# 2023-05-20 16:45:17.238 [902/model_xgboost/4662 (pid 1177)] Task finished successfully.
# 2023-05-20 16:45:28.137 [902/model_xgboost/4666 (pid 1385)] Task is starting.
# 2023-05-20 16:48:59.241 16 tasks are running: model_xgboost (16 running; 7 done).
# 2023-05-20 16:48:59.241 4 tasks are waiting in the queue.
# 2023-05-20 16:48:59.241 2 steps have not started: end, choose_model.
# 2023-05-20 16:49:07.937 [902/model_xgboost/4631 (pid 468)] Task finished successfully.
# 2023-05-20 16:49:19.340 [902/model_xgboost/4667 (pid 1437)] Task is starting.
# 2023-05-20 16:52:31.139 [902/model_xgboost/4640 (pid 797)] Task finished successfully.
# 2023-05-20 16:52:42.035 [902/model_xgboost/4668 (pid 1489)] Task is starting.
# 2023-05-20 16:53:59.740 16 tasks are running: model_xgboost (16 running; 9 done).
# 2023-05-20 16:53:59.740 2 tasks are waiting in the queue.
# 2023-05-20 16:53:59.740 2 steps have not started: end, choose_model.
# 2023-05-20 16:58:54.638 [902/model_xgboost/4665 (pid 1333)] Task finished successfully.
# 2023-05-20 16:59:06.735 [902/model_xgboost/4669 (pid 1543)] Task is starting.
# 2023-05-20 16:59:06.736 16 tasks are running: model_xgboost (16 running; 10 done).
# 2023-05-20 16:59:06.736 1 task is waiting in the queue:
# 2023-05-20 16:59:06.736 2 steps have not started: end, choose_model.
# 2023-05-20 16:59:27.037 [902/model_xgboost/4634 (pid 574)] Task finished successfully.
# 2023-05-20 16:59:36.035 [902/model_xgboost/4670 (pid 1593)] Task is starting.
# 2023-05-20 17:03:44.737 [902/model_xgboost/4643 (pid 928)] Task finished successfully.
# 2023-05-20 17:04:06.945 15 tasks are running: model_xgboost (15 running; 12 done).
# 2023-05-20 17:04:06.945 No tasks are waiting in the queue.
# 2023-05-20 17:04:06.945 2 steps have not started: end, choose_model.
# 2023-05-20 17:09:07.640 15 tasks are running: model_xgboost (15 running; 12 done).
# 2023-05-20 17:09:07.640 No tasks are waiting in the queue.
# 2023-05-20 17:09:07.640 2 steps have not started: end, choose_model.
# 2023-05-20 17:10:12.638 [902/model_xgboost/4637 (pid 700)] Task finished successfully.
# 2023-05-20 17:13:49.638 [902/model_xgboost/4663 (pid 1229)] Task finished successfully.
# 2023-05-20 17:14:07.643 13 tasks are running: model_xgboost (13 running; 14 done).
# 2023-05-20 17:14:07.643 No tasks are waiting in the queue.
# 2023-05-20 17:14:07.643 2 steps have not started: end, choose_model.
# 2023-05-20 17:16:01.738 [902/model_xgboost/4668 (pid 1489)] Task finished successfully.
# 2023-05-20 17:19:08.141 12 tasks are running: model_xgboost (12 running; 15 done).
# 2023-05-20 17:19:08.141 No tasks are waiting in the queue.
# 2023-05-20 17:19:08.141 2 steps have not started: end, choose_model.
# 2023-05-20 17:22:13.837 [902/model_xgboost/4660 (pid 1073)] Task finished successfully.
# 2023-05-20 17:24:08.636 11 tasks are running: model_xgboost (11 running; 16 done).
# 2023-05-20 17:24:08.636 No tasks are waiting in the queue.
# 2023-05-20 17:24:08.636 2 steps have not started: end, choose_model.
# 2023-05-20 17:25:23.737 [902/model_xgboost/4632 (pid 501)] Task finished successfully.
# 2023-05-20 17:26:06.538 [902/model_xgboost/4641 (pid 831)] Task finished successfully.
# 2023-05-20 17:27:07.137 [902/model_xgboost/4666 (pid 1385)] Task finished successfully.
# 2023-05-20 17:29:08.638 8 tasks are running: model_xgboost (8 running; 19 done).
# 2023-05-20 17:29:08.638 No tasks are waiting in the queue.
# 2023-05-20 17:29:08.638 2 steps have not started: end, choose_model.
# 2023-05-20 17:33:34.237 [902/model_xgboost/4635 (pid 608)] Task finished successfully.
# 2023-05-20 17:34:04.135 [902/model_xgboost/4645 (pid 947)] Task finished successfully.
# 2023-05-20 17:34:09.639 6 tasks are running: model_xgboost (6 running; 21 done).
# 2023-05-20 17:34:09.639 No tasks are waiting in the queue.
# 2023-05-20 17:34:09.639 2 steps have not started: end, choose_model.
# 2023-05-20 17:34:25.457 [902/model_xgboost/4664 (pid 1281)] Task finished successfully.
# 2023-05-20 17:35:30.458 [902/model_xgboost/4669 (pid 1543)] Task finished successfully.
# 2023-05-20 17:37:10.256 [902/model_xgboost/4638 (pid 719)] Task finished successfully.
# 2023-05-20 17:38:51.535 [902/model_xgboost/4667 (pid 1437)] Task finished successfully.
# 2023-05-20 17:38:59.607 [902/model_xgboost/4661 (pid 1125)] Task finished successfully.
# 2023-05-20 17:39:09.750 1 task is running: model_xgboost (1 running; 26 done).
# 2023-05-20 17:39:09.750 No tasks are waiting in the queue.
# 2023-05-20 17:39:09.750 2 steps have not started: end, choose_model.
# 2023-05-20 17:39:51.829 [902/model_xgboost/4670 (pid 1593)] Task finished successfully.
# 2023-05-20 17:39:52.757 [902/choose_model/4728 (pid 1917)] Task is starting.
# 2023-05-20 17:40:10.094 [902/choose_model/4728 (pid 1917)] Task finished successfully.
# 2023-05-20 17:40:10.999 [902/end/4729 (pid 2066)] Task is starting.
# 2023-05-20 17:40:11.924 [902/end/4729 (pid 2066)] Scores:
# 2023-05-20 17:40:12.800 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:12.800 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:12.800 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:12.800 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:12.801 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:12.801 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.05, max_bin=None,
# 2023-05-20 17:40:12.801 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:12.801 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=4, max_leaves=None,
# 2023-05-20 17:40:12.801 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:12.801 [902/end/4729 (pid 2066)] n_estimators=100, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:12.801 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.930608
# 2023-05-20 17:40:12.801 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:12.801 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:12.801 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:12.801 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:12.801 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:12.801 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.05, max_bin=None,
# 2023-05-20 17:40:12.801 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:12.801 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=5, max_leaves=None,
# 2023-05-20 17:40:12.801 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:12.802 [902/end/4729 (pid 2066)] n_estimators=100, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:12.802 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.930598
# 2023-05-20 17:40:12.802 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:12.802 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:12.802 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:12.802 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:12.802 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:12.802 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.1, max_bin=None,
# 2023-05-20 17:40:12.802 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:12.802 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=4, max_leaves=None,
# 2023-05-20 17:40:12.802 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:12.802 [902/end/4729 (pid 2066)] n_estimators=100, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:12.802 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.930546
# 2023-05-20 17:40:12.802 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:12.802 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:12.803 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:12.803 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:12.803 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:12.803 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.05, max_bin=None,
# 2023-05-20 17:40:12.803 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:12.803 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=6, max_leaves=None,
# 2023-05-20 17:40:12.803 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:12.803 [902/end/4729 (pid 2066)] n_estimators=100, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:12.803 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.930519
# 2023-05-20 17:40:12.803 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:12.803 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:12.803 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:12.803 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:12.803 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:12.804 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.05, max_bin=None,
# 2023-05-20 17:40:12.804 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:12.804 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=4, max_leaves=None,
# 2023-05-20 17:40:12.804 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:12.804 [902/end/4729 (pid 2066)] n_estimators=250, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:12.804 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.930417
# 2023-05-20 17:40:12.804 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:12.804 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:12.804 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:12.804 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:12.804 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:12.804 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.1, max_bin=None,
# 2023-05-20 17:40:12.804 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:12.804 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=5, max_leaves=None,
# 2023-05-20 17:40:12.805 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:12.805 [902/end/4729 (pid 2066)] n_estimators=100, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:12.805 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.930385
# 2023-05-20 17:40:12.805 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:12.805 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:12.805 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:12.805 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:12.805 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:12.805 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.05, max_bin=None,
# 2023-05-20 17:40:12.805 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:12.805 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=5, max_leaves=None,
# 2023-05-20 17:40:12.805 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:12.805 [902/end/4729 (pid 2066)] n_estimators=250, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:12.805 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.930284
# 2023-05-20 17:40:12.805 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:12.806 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:12.806 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:12.806 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:12.806 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:12.806 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.1, max_bin=None,
# 2023-05-20 17:40:12.806 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:12.806 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=6, max_leaves=None,
# 2023-05-20 17:40:12.806 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:12.806 [902/end/4729 (pid 2066)] n_estimators=100, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:12.806 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.930262
# 2023-05-20 17:40:12.806 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:12.806 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:12.806 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:12.806 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:12.807 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:12.807 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.05, max_bin=None,
# 2023-05-20 17:40:12.807 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:12.807 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=6, max_leaves=None,
# 2023-05-20 17:40:12.807 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:12.807 [902/end/4729 (pid 2066)] n_estimators=250, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:12.807 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.930110
# 2023-05-20 17:40:12.807 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:12.807 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:12.807 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:12.807 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:12.807 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:12.807 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.05, max_bin=None,
# 2023-05-20 17:40:12.807 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:12.807 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=4, max_leaves=None,
# 2023-05-20 17:40:12.808 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:12.808 [902/end/4729 (pid 2066)] n_estimators=500, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:12.808 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.929869
# 2023-05-20 17:40:12.808 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:12.808 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:12.808 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:12.808 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:12.808 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:12.808 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.1, max_bin=None,
# 2023-05-20 17:40:12.808 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:12.808 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=4, max_leaves=None,
# 2023-05-20 17:40:12.808 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:12.808 [902/end/4729 (pid 2066)] n_estimators=250, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:12.808 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.929846
# 2023-05-20 17:40:12.808 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:12.808 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:12.809 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:12.809 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:12.809 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:12.809 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.25, max_bin=None,
# 2023-05-20 17:40:12.809 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:12.809 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=4, max_leaves=None,
# 2023-05-20 17:40:12.809 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:12.809 [902/end/4729 (pid 2066)] n_estimators=100, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:12.809 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.929784
# 2023-05-20 17:40:12.809 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:12.809 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:12.809 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:12.809 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:12.809 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:12.810 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.05, max_bin=None,
# 2023-05-20 17:40:12.810 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:12.810 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=5, max_leaves=None,
# 2023-05-20 17:40:12.810 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:12.810 [902/end/4729 (pid 2066)] n_estimators=500, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:12.810 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.929531
# 2023-05-20 17:40:12.810 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:12.810 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:12.810 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:12.810 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:12.810 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:12.810 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.1, max_bin=None,
# 2023-05-20 17:40:12.810 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:12.811 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=5, max_leaves=None,
# 2023-05-20 17:40:12.811 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:12.811 [902/end/4729 (pid 2066)] n_estimators=250, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:12.811 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.929462
# 2023-05-20 17:40:12.811 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:12.811 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:12.811 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:12.811 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:12.811 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:12.811 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.25, max_bin=None,
# 2023-05-20 17:40:12.811 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:12.811 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=5, max_leaves=None,
# 2023-05-20 17:40:12.812 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:12.812 [902/end/4729 (pid 2066)] n_estimators=100, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:12.812 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.929357
# 2023-05-20 17:40:12.812 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:12.812 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:12.812 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:12.812 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:12.812 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:12.812 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.05, max_bin=None,
# 2023-05-20 17:40:12.812 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:12.812 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=6, max_leaves=None,
# 2023-05-20 17:40:12.812 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:12.812 [902/end/4729 (pid 2066)] n_estimators=500, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:12.813 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.929326
# 2023-05-20 17:40:12.813 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:12.813 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:12.813 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:12.813 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:12.813 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:12.813 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.1, max_bin=None,
# 2023-05-20 17:40:12.813 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:12.813 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=6, max_leaves=None,
# 2023-05-20 17:40:12.813 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:12.813 [902/end/4729 (pid 2066)] n_estimators=250, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:12.813 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.929287
# 2023-05-20 17:40:12.813 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:12.813 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:12.813 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:12.813 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:12.813 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:12.813 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.1, max_bin=None,
# 2023-05-20 17:40:12.814 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:12.814 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=4, max_leaves=None,
# 2023-05-20 17:40:12.814 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:12.814 [902/end/4729 (pid 2066)] n_estimators=500, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:12.814 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.929124
# 2023-05-20 17:40:12.814 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:12.814 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:12.814 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:12.814 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:12.814 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:12.814 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.25, max_bin=None,
# 2023-05-20 17:40:12.814 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:12.814 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=6, max_leaves=None,
# 2023-05-20 17:40:12.814 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:12.814 [902/end/4729 (pid 2066)] n_estimators=100, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:12.815 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.929091
# 2023-05-20 17:40:12.815 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:12.815 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:12.815 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:12.815 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:12.815 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:12.815 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.25, max_bin=None,
# 2023-05-20 17:40:12.815 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:12.815 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=4, max_leaves=None,
# 2023-05-20 17:40:12.815 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:12.815 [902/end/4729 (pid 2066)] n_estimators=250, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:12.815 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.928764
# 2023-05-20 17:40:12.815 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:12.815 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:12.815 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:12.815 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:12.816 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:12.816 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.1, max_bin=None,
# 2023-05-20 17:40:12.816 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:12.816 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=5, max_leaves=None,
# 2023-05-20 17:40:12.816 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:12.816 [902/end/4729 (pid 2066)] n_estimators=500, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:12.816 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.928593
# 2023-05-20 17:40:12.816 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:12.816 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:12.816 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:12.816 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:12.816 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:12.816 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.1, max_bin=None,
# 2023-05-20 17:40:12.816 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:12.816 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=6, max_leaves=None,
# 2023-05-20 17:40:12.816 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:12.817 [902/end/4729 (pid 2066)] n_estimators=500, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:12.817 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.928370
# 2023-05-20 17:40:14.555 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:14.556 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:14.556 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:14.556 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:14.556 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:14.556 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.25, max_bin=None,
# 2023-05-20 17:40:14.556 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:14.556 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=5, max_leaves=None,
# 2023-05-20 17:40:14.556 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:14.556 [902/end/4729 (pid 2066)] n_estimators=250, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:14.556 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.928174
# 2023-05-20 17:40:14.556 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:14.556 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:14.556 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:14.556 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:14.556 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:14.556 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.25, max_bin=None,
# 2023-05-20 17:40:14.556 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:14.556 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=4, max_leaves=None,
# 2023-05-20 17:40:14.556 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:14.556 [902/end/4729 (pid 2066)] n_estimators=500, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:14.557 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.927999
# 2023-05-20 17:40:14.557 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:14.557 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:14.557 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:14.557 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:14.557 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:14.557 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.25, max_bin=None,
# 2023-05-20 17:40:14.557 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:14.557 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=6, max_leaves=None,
# 2023-05-20 17:40:14.557 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:14.557 [902/end/4729 (pid 2066)] n_estimators=250, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:14.557 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.927849
# 2023-05-20 17:40:14.557 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:14.557 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:14.557 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:14.557 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:14.557 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:14.557 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.25, max_bin=None,
# 2023-05-20 17:40:14.557 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:14.557 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=5, max_leaves=None,
# 2023-05-20 17:40:14.557 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:14.557 [902/end/4729 (pid 2066)] n_estimators=500, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:14.558 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.927403
# 2023-05-20 17:40:14.558 [902/end/4729 (pid 2066)] XGBRegressor(base_score=None, booster=None, callbacks=None,
# 2023-05-20 17:40:14.558 [902/end/4729 (pid 2066)] colsample_bylevel=None, colsample_bynode=None,
# 2023-05-20 17:40:14.558 [902/end/4729 (pid 2066)] colsample_bytree=None, early_stopping_rounds=None,
# 2023-05-20 17:40:14.558 [902/end/4729 (pid 2066)] enable_categorical=False, eval_metric=None, feature_types=None,
# 2023-05-20 17:40:14.558 [902/end/4729 (pid 2066)] gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# 2023-05-20 17:40:14.558 [902/end/4729 (pid 2066)] interaction_constraints=None, learning_rate=0.25, max_bin=None,
# 2023-05-20 17:40:14.558 [902/end/4729 (pid 2066)] max_cat_threshold=None, max_cat_to_onehot=None,
# 2023-05-20 17:40:14.558 [902/end/4729 (pid 2066)] max_delta_step=None, max_depth=6, max_leaves=None,
# 2023-05-20 17:40:14.558 [902/end/4729 (pid 2066)] min_child_weight=None, missing=nan, monotone_constraints=None,
# 2023-05-20 17:40:14.558 [902/end/4729 (pid 2066)] n_estimators=500, n_jobs=None, num_parallel_tree=None,
# 2023-05-20 17:40:14.558 [902/end/4729 (pid 2066)] predictor=None, random_state=None, ...) 0.927106
# 2023-05-20 17:40:14.735 [902/end/4729 (pid 2066)] Task finished successfully.
# 2023-05-20 17:40:14.958 Done! See the run in the UI at https://ui-pw-535851483.outerbounds.dev/TaxiFarePrediction/902

# %%
# %%writefile ../flows/cloud/taxiprediction_challenger.py
from metaflow import FlowSpec, step, card, conda_base, current, project, Parameter, Flow, trigger, retry, timeout,catch
from metaflow.cards import Markdown, Table, Image, Artifact

URL = "https://outerbounds-datasets.s3.us-west-2.amazonaws.com/taxi/latest.parquet"
DATETIME_FORMAT = '%Y-%m-%d %H:%M:%S'

@trigger(events=['s3'])
@conda_base(libraries={'pandas': '1.4.2', 'pyarrow': '11.0.0', 'numpy': '1.21.2', 'scikit-learn': '1.1.2', 'lightgbm' : '3.3.5','xgboost' : '1.7.4'})
@project(name="taxi_fare_prediction")
class TaxiFarePrediction(FlowSpec):

    data_url = Parameter("data_url", default=URL)

    def transform_features(self, df):

        obviously_bad_data_filters = [
            df.fare_amount > 0,         
            df.trip_distance <= 100,    
            df.trip_distance > 0,
            df.passenger_count > 0,
            df.mta_tax > 0,
            df.tip_amount >= 0,
            df.tolls_amount >= 0,
            df.total_amount > 0,
            df.PULocationID !=df.DOLocationID,
            df.hour > 0
        ]

        for f in obviously_bad_data_filters:
            df = df[f]

        
        return df

    @catch(var="read_failure")
    @retry(times=4)
    @timeout(minutes=10)
    @step
    def start(self):

        import pandas as pd
        from sklearn.model_selection import train_test_split

        self.df = self.transform_features(pd.read_parquet(self.data_url))

        self.X = self.df["trip_distance"].values.reshape(-1, 1)
        self.y = self.df["total_amount"].values
        self.next(self.xgb_model)

    @step
    def xgb_model(self):
        "Fit a single variable, linear model to the data."
        from xgboost import XGBRegressor

        self.model = XGBRegressor(learning_rate=0.05,max_depth=4,n_estimators=100)

        self.next(self.validate)
                
    
    def gather_sibling_flow_run_results(self):

        # storage to populate and feed to a Table in a Metaflow card
        rows = []

        # loop through runs of this flow 
        for run in Flow(self.__class__.__name__):
            if run.id != current.run_id:
                if run.successful:
                    icon = "✅" 
                    msg = "OK"
                    score = str(run.data.scores.mean())
                else:
                    icon = "❌"
                    msg = "Error"
                    score = "NA"
                    for step in run:
                        for task in step:
                            if not task.successful:
                                msg = task.stderr
                row = [Markdown(icon), Artifact(run.id), Artifact(run.created_at.strftime(DATETIME_FORMAT)), Artifact(score), Markdown(msg)]
                rows.append(row)
            else:
                rows.append([Markdown("✅"), Artifact(run.id), Artifact(run.created_at.strftime(DATETIME_FORMAT)), Artifact(str(self.scores.mean())), Markdown("This run...")])
        return rows
                
    
    @card(type="corise")
    @step
    def validate(self):
        from sklearn.model_selection import cross_val_score
        self.scores = cross_val_score(self.model, self.X, self.y, cv=5,scoring='r2')
        current.card.append(Markdown("# Taxi Fare Prediction Challenger Results"))
        current.card.append(Table(self.gather_sibling_flow_run_results(), headers=["Pass/fail", "Run ID", "Created At", "R^2 score", "Stderr"]))
        self.next(self.end)


    @step
    def end(self):
        self.model_type = "xgboost"
        print("Score = %s" % self.scores.mean())


if __name__ == "__main__":
    TaxiFarePrediction()
# Out:
# Overwriting ../flows/cloud/taxiprediction_challenger.py

# %%
! python ../flows/cloud/taxiprediction_challenger.py --environment=conda --production --branch challenger --production argo-workflows create
# Out:
# Metaflow 2.8.6+ob(v1) executing TaxiFarePrediction for user:sandbox
# Project: taxi_fare_prediction, Branch: prod.challenger
# Validating your flow...
#     The graph looks good!
# Running pylint...
#     Pylint is happy!
# Deploying taxifareprediction.prod.challenger.taxifareprediction to Argo Workflows...
#
# The namespace of this production flow is
#     production:mfprj-6iffsxtybx6fkjku-0-crtx
# To analyze results of this production flow add this line in your notebooks:
#     namespace("production:mfprj-6iffsxtybx6fkjku-0-crtx")
# If you want to authorize other people to deploy new versions of this flow to Argo Workflows, they need to call
#     argo-workflows create --authorize mfprj-6iffsxtybx6fkjku-0-crtx
# when deploying this flow to Argo Workflows for the first time.
# See "Organizing Results" at https://docs.metaflow.org/ for more information about production tokens.
#
# Bootstrapping conda environment...(this could take a few minutes)
# Workflow taxifareprediction.prod.challenger.taxifareprediction for flow TaxiFarePrediction pushed to Argo Workflows successfully.
#
# Note that the flow was deployed with a modified name due to Kubernetes naming conventions
# on Argo Workflows. The original flow name is stored in the workflow annotation.
#
# What will trigger execution of the workflow:
#     This workflow triggers automatically when the upstream s3 event is/are published.

# %%
! python ../flows/cloud/taxiprediction_challenger.py --environment=conda --production --branch challenger --production argo-workflows trigger
# Out:
# Metaflow 2.8.6+ob(v1) executing TaxiFarePrediction for user:sandbox
# Project: taxi_fare_prediction, Branch: prod.challenger
# Validating your flow...
#     The graph looks good!
# Running pylint...
#     Pylint is happy!
# Workflow taxifareprediction.prod.challenger.taxifareprediction triggered on Argo Workflows (run-id argo-taxifareprediction.prod.challenger.taxifareprediction-wvvpc).
# See the run in the UI at https://ui-pw-535851483.outerbounds.dev/TaxiFarePrediction/argo-taxifareprediction.prod.challenger.taxifareprediction-wvvpc

# %% [markdown]
# ## Task 3: Analyze the results
# Return to this notebook, and read in the results of the challenger and champion flow using the Metaflow Client API.
# <br><br>

# %%
from metaflow import Flow, namespace
import numpy as np

CHAMPION_MODEL_NAMESPACE = 'production:mfprj-ovzw7jjg7psagpyw-0-pcke'
CHALLENGER_MODEL_NAMESPACE = 'production:mfprj-6iffsxtybx6fkjku-0-crtx'

best_score = -1; winner = None; winner_namespace = None
for n in [CHAMPION_MODEL_NAMESPACE, CHALLENGER_MODEL_NAMESPACE]:
    namespace(n)
    run = Flow('TaxiFarePrediction').latest_successful_run
    acc_score = np.mean(run.data.scores)
    print("Latest {} model had accuracy = {}%".format(run.data.model_type, acc_score))
    if acc_score > best_score:
        best_score = acc_score
        winner = run.data.model_type
        winner_namespace = n
print("Winner is  {} model  with accuracy of {}%".format(winner, round(100*best_score, 2)))
# Out:
# Latest baseline model had accuracy = 0.9198880750324298%
# Latest xgboost model had accuracy = 0.9304976303014122%
# Winner is  xgboost model  with accuracy of 93.05%

# %% [markdown]
# #### Questions
# - Does your model perform better on the metrics you selected?
#
# Ans: Yes, challenger model marginally perform better than champion model.
#
# - Think about your day job, how would you go about assessing whether to roll forward the production "champion" to your new model?
#     - What gives you confidence one model is better than another?
#     - What kinds of information do you need to monitor to get buy-in from stakeholders that model A is preferable to model B?
#
# Ans: Based on the metrics chosen, which is R^2 score, the challenger model seem to perform better marginally. However, the question is whether it consistently perform better and hence it needs to be monitored over a period of time with inflow of realtime data.
# To ensure which model is preferable, a number of factors come into play based on the problem at hand. Some of them are: Ease of deployment of the new model compared to existing ones, what metrics are we monitoring based on the problem being solved, the latency of prediction, whether the increase in performance is really worth it compared to the tradeoff at which this performance is achieved etc.

# %% [markdown]
# ## CONGRATULATIONS! 🎉✨🍾
# If you made it this far, you have completed the Full Stack Machine Learning Corise course.
# We are so glad that you chose to learn with us, and hope to see you again in future courses. Stay tuned for more content and come join us in [Slack](http://slack.outerbounds.co/) to keep learning about Metaflow!
